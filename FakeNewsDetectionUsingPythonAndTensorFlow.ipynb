# %%
import numpy as np
import pandas as pd
import json
import csv
import random
  
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import to_categorical
from tensorflow.keras import regularizers
  
import pprint
import tensorflow.compat.v1 as tf
from tensorflow.python.framework import ops
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
tf.disable_eager_execution()
  
# Reading the data
data = pd.read_csv("news.csv")
data.head()
# Out:
#    Unnamed: 0                                              title  \
# 0        8476                       You Can Smell Hillary’s Fear
# 1       10294  Watch The Exact Moment Paul Ryan Committed Pol...
# 2        3608        Kerry to go to Paris in gesture of sympathy
# 3       10142  Bernie supporters on Twitter erupt in anger ag...
# 4         875   The Battle of New York: Why This Primary Matters
#
#                                                 text label
# 0  Daniel Greenfield, a Shillman Journalism Fello...  FAKE
# 1  Google Pinterest Digg Linkedin Reddit Stumbleu...  FAKE
# 2  U.S. Secretary of State John F. Kerry said Mon...  REAL
# 3  — Kaydee King (@KaydeeKing) November 9, 2016 T...  FAKE
# 4  It's primary day in New York and front-runners...  REAL

# %%
data = data.drop(["Unnamed: 0"], axis=1)
data.head(5)
# Out:
#                                                title  \
# 0                       You Can Smell Hillary’s Fear
# 1  Watch The Exact Moment Paul Ryan Committed Pol...
# 2        Kerry to go to Paris in gesture of sympathy
# 3  Bernie supporters on Twitter erupt in anger ag...
# 4   The Battle of New York: Why This Primary Matters
#
#                                                 text label
# 0  Daniel Greenfield, a Shillman Journalism Fello...  FAKE
# 1  Google Pinterest Digg Linkedin Reddit Stumbleu...  FAKE
# 2  U.S. Secretary of State John F. Kerry said Mon...  REAL
# 3  — Kaydee King (@KaydeeKing) November 9, 2016 T...  FAKE
# 4  It's primary day in New York and front-runners...  REAL

# %%
le = preprocessing.LabelEncoder()
le.fit(data['label'])
data['label'] = le.transform(data['label'])

# %%
embedding_dim = 50
max_length = 54
trunc_type = 'post'
padding_type = 'post'
oov_tok = "<OOV>"
training_size = 3000
test_portion = .1

# %%
title = []
text = []
labels = []
for x in range(training_size):
    title.append(data['title'][x])
    text.append(data['text'][x])
    labels.append(data['label'][x])

# %%
tokenizer1 = Tokenizer()
tokenizer1.fit_on_texts(title)
word_index1 = tokenizer1.word_index
vocab_size1 = len(word_index1)
sequences1 = tokenizer1.texts_to_sequences(title)
padded1 = pad_sequences(
    sequences1,  padding=padding_type, truncating=trunc_type)
split = int(test_portion * training_size)
training_sequences1 = padded1[split:training_size]
test_sequences1 = padded1[0:split]
test_labels = labels[0:split]
training_labels = labels[split:training_size]

# %%
embeddings_index = {}
file = open('glove.6B.50d.txt', encoding="utf8")
#with open('glove.6B.50d.txt') as f:
    for line in file:
        values = line.split()
        word = values[0]
        coefs = np.asarray(values[1:], dtype='float32')
        embeddings_index[word] = coefs
  
# Generating embeddings
embeddings_matrix = np.zeros((vocab_size1+1, embedding_dim))
for word, i in word_index1.items():
    embedding_vector = embeddings_index.get(word)
    if embedding_vector is not None:
        embeddings_matrix[i] = embedding_vector

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Embedding(vocab_size1+1, embedding_dim,
                              input_length=max_length, weights=[
                                  embeddings_matrix],
                              trainable=False),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Conv1D(64, 5, activation='relu'),
    tf.keras.layers.MaxPooling1D(pool_size=4),
    tf.keras.layers.LSTM(64),
    tf.keras.layers.Dense(1, activation='sigmoid')
])
model.compile(loss='binary_crossentropy',
              optimizer='adam', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 54, 50)            377600
#
#  dropout (Dropout)           (None, 54, 50)            0
#
#  conv1d (Conv1D)             (None, 50, 64)            16064
#
#  max_pooling1d (MaxPooling1D  (None, 12, 64)           0
#  )
#
#  lstm (LSTM)                 (None, 64)                33024
#
#  dense (Dense)               (None, 1)                 65
#
# =================================================================
# Total params: 426,753
# Trainable params: 49,153
# Non-trainable params: 377,600
# _________________________________________________________________

# %%
num_epochs = 50
  
training_padded = np.array(training_sequences1)
training_labels = np.array(training_labels)
testing_padded = np.array(test_sequences1)
testing_labels = np.array(test_labels)
  
history = model.fit(training_padded, training_labels, 
                    epochs=num_epochs,
                    validation_data=(testing_padded,
                                     testing_labels), 
                    verbose=2)
# Out:
# Train on 2700 samples, validate on 300 samples
# Epoch 1/50
# C:\Users\neera\anaconda3\lib\site-packages\keras\engine\training_v1.py:2333: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates = self.state_updates
# 2700/2700 - 3s - loss: 0.6434 - accuracy: 0.6130 - val_loss: 0.5948 - val_accuracy: 0.6767 - 3s/epoch - 1ms/sample
# Epoch 2/50
# 2700/2700 - 1s - loss: 0.5714 - accuracy: 0.7059 - val_loss: 0.5527 - val_accuracy: 0.6767 - 1s/epoch - 537us/sample
# Epoch 3/50
# 2700/2700 - 1s - loss: 0.5168 - accuracy: 0.7363 - val_loss: 0.5278 - val_accuracy: 0.6833 - 1s/epoch - 474us/sample
# Epoch 4/50
# 2700/2700 - 1s - loss: 0.4790 - accuracy: 0.7652 - val_loss: 0.5232 - val_accuracy: 0.7100 - 1s/epoch - 466us/sample
# Epoch 5/50
# 2700/2700 - 2s - loss: 0.4042 - accuracy: 0.8193 - val_loss: 0.5168 - val_accuracy: 0.7167 - 2s/epoch - 594us/sample
# Epoch 6/50
# 2700/2700 - 3s - loss: 0.3740 - accuracy: 0.8367 - val_loss: 0.5155 - val_accuracy: 0.7500 - 3s/epoch - 952us/sample
# Epoch 7/50
# 2700/2700 - 1s - loss: 0.3470 - accuracy: 0.8504 - val_loss: 0.5028 - val_accuracy: 0.7533 - 1s/epoch - 532us/sample
# Epoch 8/50
# 2700/2700 - 1s - loss: 0.2938 - accuracy: 0.8741 - val_loss: 0.5066 - val_accuracy: 0.7467 - 1s/epoch - 516us/sample
# Epoch 9/50
# 2700/2700 - 1s - loss: 0.2742 - accuracy: 0.8922 - val_loss: 0.6361 - val_accuracy: 0.7333 - 1s/epoch - 503us/sample
# Epoch 10/50
# 2700/2700 - 1s - loss: 0.2557 - accuracy: 0.8900 - val_loss: 0.5417 - val_accuracy: 0.7533 - 1s/epoch - 512us/sample
# Epoch 11/50
# 2700/2700 - 1s - loss: 0.2220 - accuracy: 0.9037 - val_loss: 0.6168 - val_accuracy: 0.7400 - 1s/epoch - 524us/sample
# Epoch 12/50
# 2700/2700 - 1s - loss: 0.2187 - accuracy: 0.9067 - val_loss: 0.5425 - val_accuracy: 0.7633 - 1s/epoch - 468us/sample
# Epoch 13/50
# 2700/2700 - 1s - loss: 0.1968 - accuracy: 0.9267 - val_loss: 0.6865 - val_accuracy: 0.7433 - 1s/epoch - 474us/sample
# Epoch 14/50
# 2700/2700 - 1s - loss: 0.2004 - accuracy: 0.9152 - val_loss: 0.6107 - val_accuracy: 0.7733 - 1s/epoch - 429us/sample
# Epoch 15/50
# 2700/2700 - 1s - loss: 0.1682 - accuracy: 0.9326 - val_loss: 0.6890 - val_accuracy: 0.7600 - 1s/epoch - 471us/sample
# Epoch 16/50
# 2700/2700 - 1s - loss: 0.1700 - accuracy: 0.9270 - val_loss: 0.6844 - val_accuracy: 0.7500 - 1s/epoch - 485us/sample
# Epoch 17/50
# 2700/2700 - 1s - loss: 0.1613 - accuracy: 0.9404 - val_loss: 0.6331 - val_accuracy: 0.7467 - 1s/epoch - 424us/sample
# Epoch 18/50
# 2700/2700 - 1s - loss: 0.1375 - accuracy: 0.9444 - val_loss: 0.7741 - val_accuracy: 0.7600 - 1s/epoch - 492us/sample
# Epoch 19/50
# 2700/2700 - 1s - loss: 0.1348 - accuracy: 0.9419 - val_loss: 0.6347 - val_accuracy: 0.7700 - 1s/epoch - 442us/sample
# Epoch 20/50
# 2700/2700 - 1s - loss: 0.1368 - accuracy: 0.9489 - val_loss: 0.7047 - val_accuracy: 0.7367 - 1s/epoch - 469us/sample
# Epoch 21/50
# 2700/2700 - 1s - loss: 0.1205 - accuracy: 0.9544 - val_loss: 0.6942 - val_accuracy: 0.7633 - 1s/epoch - 452us/sample
# Epoch 22/50
# 2700/2700 - 1s - loss: 0.1115 - accuracy: 0.9622 - val_loss: 0.7271 - val_accuracy: 0.7733 - 1s/epoch - 418us/sample
# Epoch 23/50
# 2700/2700 - 1s - loss: 0.1320 - accuracy: 0.9481 - val_loss: 0.5950 - val_accuracy: 0.7733 - 1s/epoch - 397us/sample
# Epoch 24/50
# 2700/2700 - 1s - loss: 0.1084 - accuracy: 0.9578 - val_loss: 0.6172 - val_accuracy: 0.7767 - 1s/epoch - 400us/sample
# Epoch 25/50
# 2700/2700 - 1s - loss: 0.1082 - accuracy: 0.9604 - val_loss: 0.6867 - val_accuracy: 0.7733 - 1s/epoch - 426us/sample
# Epoch 26/50
# 2700/2700 - 1s - loss: 0.0862 - accuracy: 0.9667 - val_loss: 0.6421 - val_accuracy: 0.7900 - 1s/epoch - 392us/sample
# Epoch 27/50
# 2700/2700 - 1s - loss: 0.0950 - accuracy: 0.9644 - val_loss: 0.6508 - val_accuracy: 0.7767 - 1s/epoch - 405us/sample
# Epoch 28/50
# 2700/2700 - 1s - loss: 0.1062 - accuracy: 0.9559 - val_loss: 0.8347 - val_accuracy: 0.7800 - 1s/epoch - 415us/sample
# Epoch 29/50
# 2700/2700 - 1s - loss: 0.0939 - accuracy: 0.9667 - val_loss: 0.8249 - val_accuracy: 0.7500 - 1s/epoch - 434us/sample
# Epoch 30/50
# 2700/2700 - 1s - loss: 0.0966 - accuracy: 0.9630 - val_loss: 0.6546 - val_accuracy: 0.7700 - 1s/epoch - 450us/sample
# Epoch 31/50
# 2700/2700 - 1s - loss: 0.0928 - accuracy: 0.9630 - val_loss: 0.7745 - val_accuracy: 0.7700 - 1s/epoch - 407us/sample
# Epoch 32/50
# 2700/2700 - 1s - loss: 0.0785 - accuracy: 0.9715 - val_loss: 0.7314 - val_accuracy: 0.7633 - 1s/epoch - 408us/sample
# Epoch 33/50
# 2700/2700 - 1s - loss: 0.0819 - accuracy: 0.9693 - val_loss: 0.8199 - val_accuracy: 0.7667 - 1s/epoch - 405us/sample
# Epoch 34/50
# 2700/2700 - 1s - loss: 0.0767 - accuracy: 0.9696 - val_loss: 0.7276 - val_accuracy: 0.7733 - 1s/epoch - 402us/sample
# Epoch 35/50
# 2700/2700 - 1s - loss: 0.0860 - accuracy: 0.9648 - val_loss: 0.7457 - val_accuracy: 0.7800 - 1s/epoch - 396us/sample
# Epoch 36/50
# 2700/2700 - 1s - loss: 0.0713 - accuracy: 0.9759 - val_loss: 0.7856 - val_accuracy: 0.7700 - 1s/epoch - 389us/sample
# Epoch 37/50
# 2700/2700 - 1s - loss: 0.0654 - accuracy: 0.9767 - val_loss: 0.8034 - val_accuracy: 0.7467 - 1s/epoch - 447us/sample
# Epoch 38/50
# 2700/2700 - 1s - loss: 0.0743 - accuracy: 0.9704 - val_loss: 0.7171 - val_accuracy: 0.7800 - 1s/epoch - 420us/sample
# Epoch 39/50
# 2700/2700 - 1s - loss: 0.0755 - accuracy: 0.9741 - val_loss: 0.7610 - val_accuracy: 0.7733 - 1s/epoch - 387us/sample
# Epoch 40/50
# 2700/2700 - 1s - loss: 0.0741 - accuracy: 0.9733 - val_loss: 0.7194 - val_accuracy: 0.7767 - 1s/epoch - 385us/sample
# Epoch 41/50
# 2700/2700 - 1s - loss: 0.0747 - accuracy: 0.9719 - val_loss: 0.7676 - val_accuracy: 0.7800 - 1s/epoch - 376us/sample
# Epoch 42/50
# 2700/2700 - 1s - loss: 0.0537 - accuracy: 0.9826 - val_loss: 0.7559 - val_accuracy: 0.7833 - 987ms/epoch - 366us/sample
# Epoch 43/50
# 2700/2700 - 1s - loss: 0.0839 - accuracy: 0.9663 - val_loss: 0.7720 - val_accuracy: 0.7567 - 1s/epoch - 400us/sample
# Epoch 44/50
# 2700/2700 - 1s - loss: 0.0632 - accuracy: 0.9741 - val_loss: 1.0152 - val_accuracy: 0.7533 - 1s/epoch - 406us/sample
# Epoch 45/50
# 2700/2700 - 1s - loss: 0.0483 - accuracy: 0.9822 - val_loss: 0.8819 - val_accuracy: 0.7767 - 1s/epoch - 426us/sample
# Epoch 46/50
# 2700/2700 - 1s - loss: 0.0716 - accuracy: 0.9756 - val_loss: 0.9102 - val_accuracy: 0.7600 - 1s/epoch - 430us/sample
# Epoch 47/50
# 2700/2700 - 1s - loss: 0.0649 - accuracy: 0.9748 - val_loss: 1.0421 - val_accuracy: 0.7600 - 1s/epoch - 403us/sample
# Epoch 48/50
# 2700/2700 - 1s - loss: 0.0747 - accuracy: 0.9756 - val_loss: 0.8876 - val_accuracy: 0.7667 - 1s/epoch - 409us/sample
# Epoch 49/50
# 2700/2700 - 1s - loss: 0.0652 - accuracy: 0.9744 - val_loss: 0.7767 - val_accuracy: 0.7700 - 1s/epoch - 376us/sample
# Epoch 50/50
# 2700/2700 - 1s - loss: 0.0648 - accuracy: 0.9763 - val_loss: 0.7995 - val_accuracy: 0.7767 - 998ms/epoch - 370us/sample

# %%
# sample text to check if fake or not
X = "Karry to go to France in gesture of sympathy"
  
# detection
sequences = tokenizer1.texts_to_sequences([X])[0]
sequences = pad_sequences([sequences], maxlen=54,
                          padding=padding_type, 
                          truncating=trunc_type)
if(model.predict(sequences, verbose=0)[0][0] >= 0.5):
    print("This news is True")
else:
    print("This news is false")
# Out:
# C:\Users\neera\anaconda3\lib\site-packages\keras\engine\training_v1.py:2357: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
# This news is false
